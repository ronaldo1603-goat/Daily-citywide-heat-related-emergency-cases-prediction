# %% [markdown]
# <a href="https://colab.research.google.com/github/ronaldo1603-goat/Daily-citywide-heat-related-emergency-cases-prediction/blob/main/loading_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
base = "https://raw.githubusercontent.com/nychealth/heat-syndrome-data/master/"
df = pd.concat([pd.read_csv(base+"edheat1720_supp.csv"),
                pd.read_csv(base+"edheat2021_live.csv")], ignore_index=True)
df.head()
# Out:
#    END_DATE  MAX_DAILY_TEMP  HEAT_ED_VISIT_COUNT
# 0  5/1/2017              73                    0
# 1  5/2/2017              78                    0
# 2  5/3/2017              72                    0
# 3  5/4/2017              66                    0
# 4  5/5/2017              64                    0

# %%
x = df['MAX_DAILY_TEMP']
y = df['HEAT_ED_VISIT_COUNT']
plt.scatter(x,y)

# %%
# !git mv
# Out:
# fatal: not a git repository (or any of the parent directories): .git
